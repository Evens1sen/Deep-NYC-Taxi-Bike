# %%
import numpy as np
import pandas as pd

# %%
taxi_inflow = np.load("/home/cseadmin/mhy/data-NYCTaxi/60min/2019-2020-graph-inflow.npz")['arr_0']
taxi_outflow = np.load("/home/cseadmin/mhy/data-NYCTaxi/60min/2019-2020-graph-outflow.npz")['arr_0']

# taxi_flow = np.zeros((taxi_inflow.shape[0], taxi_inflow.shape[1], 2))
# taxi_flow[:, :, 0] = taxi_inflow.copy()
# taxi_flow[:, :, 1] = taxi_outflow.copy()

# np.savez_compressed("../data-NYCTaxi/60min/taxi_inoutflow.npz", taxi_flow)

# %%
timestamp = pd.date_range('2019-01-01', '2021-01-01', freq='60min')
timestamp = timestamp[: -1]
timestamp
# Out:
# DatetimeIndex(['2019-01-01 00:00:00', '2019-01-01 01:00:00',
#                '2019-01-01 02:00:00', '2019-01-01 03:00:00',
#                '2019-01-01 04:00:00', '2019-01-01 05:00:00',
#                '2019-01-01 06:00:00', '2019-01-01 07:00:00',
#                '2019-01-01 08:00:00', '2019-01-01 09:00:00',
#                ...
#                '2020-12-31 14:00:00', '2020-12-31 15:00:00',
#                '2020-12-31 16:00:00', '2020-12-31 17:00:00',
#                '2020-12-31 18:00:00', '2020-12-31 19:00:00',
#                '2020-12-31 20:00:00', '2020-12-31 21:00:00',
#                '2020-12-31 22:00:00', '2020-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=17544, freq='60T')

# %%
inflow = pd.DataFrame(taxi_inflow)
inflow.shape
inflow = inflow.set_index(timestamp)
inflow
# Out:
#                        0    1     2     3      4     5      6     7      8   \
# 2019-01-01 00:00:00  49.0  4.0  64.0  53.0   84.0  52.0  272.0  36.0  487.0
# 2019-01-01 01:00:00  94.0  3.0  52.0  51.0  137.0  77.0  260.0  60.0  594.0
# 2019-01-01 02:00:00  84.0  7.0  37.0  47.0   93.0  45.0   79.0  37.0  680.0
# 2019-01-01 03:00:00  85.0  1.0  13.0  27.0   72.0  42.0   22.0  43.0  496.0
# 2019-01-01 04:00:00  43.0  1.0  13.0  17.0   40.0  31.0   11.0  23.0  445.0
# ...                   ...  ...   ...   ...    ...   ...    ...   ...    ...
# 2020-12-31 19:00:00  20.0  0.0  87.0  57.0   64.0  23.0  124.0  25.0  307.0
# 2020-12-31 20:00:00  26.0  0.0  88.0  67.0   77.0  35.0  126.0  32.0  418.0
# 2020-12-31 21:00:00  23.0  1.0  62.0  70.0   93.0  45.0  107.0  24.0  357.0
# 2020-12-31 22:00:00  31.0  1.0  42.0  48.0   95.0  57.0   78.0  17.0  318.0
# 2020-12-31 23:00:00  27.0  0.0  29.0  40.0   50.0  41.0   78.0  21.0  248.0
#
# ...

# %%
h5 = pd.HDFStore('../data-NYCTaxi/60min/taxi-timestamp-inflow.h5','w')
h5['data'] = inflow
h5.close()

# %%
data=pd.read_hdf('../data-NYCTaxi/60min/taxi-timestamp-inflow.h5')
data
# Out:
#                        0    1     2     3      4     5      6     7      8   \
# 2019-01-01 00:00:00  49.0  4.0  64.0  53.0   84.0  52.0  272.0  36.0  487.0
# 2019-01-01 01:00:00  94.0  3.0  52.0  51.0  137.0  77.0  260.0  60.0  594.0
# 2019-01-01 02:00:00  84.0  7.0  37.0  47.0   93.0  45.0   79.0  37.0  680.0
# 2019-01-01 03:00:00  85.0  1.0  13.0  27.0   72.0  42.0   22.0  43.0  496.0
# 2019-01-01 04:00:00  43.0  1.0  13.0  17.0   40.0  31.0   11.0  23.0  445.0
# ...                   ...  ...   ...   ...    ...   ...    ...   ...    ...
# 2020-12-31 19:00:00  20.0  0.0  87.0  57.0   64.0  23.0  124.0  25.0  307.0
# 2020-12-31 20:00:00  26.0  0.0  88.0  67.0   77.0  35.0  126.0  32.0  418.0
# 2020-12-31 21:00:00  23.0  1.0  62.0  70.0   93.0  45.0  107.0  24.0  357.0
# 2020-12-31 22:00:00  31.0  1.0  42.0  48.0   95.0  57.0   78.0  17.0  318.0
# 2020-12-31 23:00:00  27.0  0.0  29.0  40.0   50.0  41.0   78.0  21.0  248.0
#
# ...

# %%
outflow = pd.DataFrame(taxi_outflow)
outflow = outflow.set_index(timestamp)
h5 = pd.HDFStore('../data-NYCTaxi/60min/taxi-timestamp-outflow.h5','w')
h5['data'] = outflow
h5.close()

# %%
bike_inflow = np.load('/home/cseadmin/mhy/data-NYCBike/60min/2019-2020-graph-inflow.npz')['arr_0']
bike_outflow = np.load('/home/cseadmin/mhy/data-NYCBike/60min/2019-2020-graph-outflow.npz')['arr_0']

inflow = pd.DataFrame(bike_inflow)
inflow = inflow.set_index(timestamp)
h5 = pd.HDFStore('../data-NYCBike/60min/bike-timestamp-inflow.h5','w')
h5['data'] = inflow
h5.close()

outflow = pd.DataFrame(bike_outflow)
outflow = outflow.set_index(timestamp)
h5 = pd.HDFStore('../data-NYCBike/60min/bike-timestamp-outflow.h5','w')
h5['data'] = outflow
h5.close()

# %%
bike_flow = np.load("/home/cseadmin/mhy/data-NYCBike/60min/2019-2020-graph-inoutflow.npz")['arr_0']
taxi_flow = np.load("/home/cseadmin/mhy/data-NYCTaxi/60min/taxi_inoutflow.npz")['arr_0']

taxi_flow.shape
# Out:
# (17544, 69, 2)

# %%
flow = np.zeros((bike_flow.shape[0], bike_flow.shape[1],  4))
flow[:, :, 0:2] = bike_flow.copy()
flow[:, :, 2:4] = taxi_flow.copy()

np.savez_compressed("../data-NYCTaxi/60min/bike_taxi_inoutflow.npz", flow)
